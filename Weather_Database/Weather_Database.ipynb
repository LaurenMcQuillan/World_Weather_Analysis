# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 753

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | zhangye
# Processing Record 3 of Set 1 | lompoc
# Processing Record 4 of Set 1 | launceston
# Processing Record 5 of Set 1 | cartersville
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | axim
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | boma
# Processing Record 12 of Set 1 | pochutla
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | port blair
# Processing Record 16 of Set 1 | souillac
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | eureka
# Processing Record 20 of Set 1 | boddam
# Processing Record 21 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | pemba
# Processing Record 24 of Set 1 | ilulissat
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | saint-augustin
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | vila franca do campo
# Processing Record 31 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 1 | talnakh
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | acapulco
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | auki
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | kon tum
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | lugoba
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | alanya
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | hirara
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | grindavik
# Processing Record 2 of Set 2 | adrar
# Processing Record 3 of Set 2 | stornoway
# Processing Record 4 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 2 | burica
# City not found. Skipping...
# Processing Record 6 of Set 2 | fort nelson
# Processing Record 7 of Set 2 | moron
# Processing Record 8 of Set 2 | viedma
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | sitka
# Processing Record 11 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | qesarya
# Processing Record 14 of Set 2 | west bay
# Processing Record 15 of Set 2 | morbegno
# Processing Record 16 of Set 2 | yarensk
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | bengkulu
# Processing Record 19 of Set 2 | mar del plata
# Processing Record 20 of Set 2 | ambagarh chauki
# Processing Record 21 of Set 2 | praia da vitoria
# Processing Record 22 of Set 2 | fortuna
# Processing Record 23 of Set 2 | vestmannaeyjar
# Processing Record 24 of Set 2 | broome
# Processing Record 25 of Set 2 | muisne
# Processing Record 26 of Set 2 | faanui
# Processing Record 27 of Set 2 | sinnamary
# Processing Record 28 of Set 2 | mogok
# Processing Record 29 of Set 2 | kloulklubed
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | rocha
# Processing Record 32 of Set 2 | zhumadian
# Processing Record 33 of Set 2 | benemerito de las americas
# Processing Record 34 of Set 2 | belaya
# Processing Record 35 of Set 2 | flin flon
# Processing Record 36 of Set 2 | konosha
# Processing Record 37 of Set 2 | kaitangata
# Processing Record 38 of Set 2 | ponta do sol
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | kamenka
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | talah
# City not found. Skipping...
# Processing Record 43 of Set 2 | talaya
# Processing Record 44 of Set 2 | airai
# Processing Record 45 of Set 2 | santa fe
# Processing Record 46 of Set 2 | camana
# Processing Record 47 of Set 2 | codrington
# Processing Record 48 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | molchanovo
# Processing Record 1 of Set 3 | chinhoyi
# Processing Record 2 of Set 3 | at-bashi
# Processing Record 3 of Set 3 | sao joao da barra
# Processing Record 4 of Set 3 | tura
# Processing Record 5 of Set 3 | henties bay
# Processing Record 6 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 3 | kahului
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | altay
# Processing Record 10 of Set 3 | novoagansk
# Processing Record 11 of Set 3 | aswan
# Processing Record 12 of Set 3 | moss vale
# Processing Record 13 of Set 3 | hirado
# Processing Record 14 of Set 3 | filadelfia
# Processing Record 15 of Set 3 | nanortalik
# Processing Record 16 of Set 3 | cherskiy
# Processing Record 17 of Set 3 | kushiro
# Processing Record 18 of Set 3 | camacupa
# Processing Record 19 of Set 3 | korla
# Processing Record 20 of Set 3 | oktyabrskoye
# Processing Record 21 of Set 3 | vostok
# Processing Record 22 of Set 3 | lagoa
# Processing Record 23 of Set 3 | soyo
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | maldonado
# Processing Record 26 of Set 3 | doha
# Processing Record 27 of Set 3 | dinsor
# City not found. Skipping...
# Processing Record 28 of Set 3 | bemidji
# Processing Record 29 of Set 3 | castro
# Processing Record 30 of Set 3 | puerto ayora
# Processing Record 31 of Set 3 | hay river
# Processing Record 32 of Set 3 | hualmay
# Processing Record 33 of Set 3 | fairbanks
# Processing Record 34 of Set 3 | svistov
# City not found. Skipping...
# Processing Record 35 of Set 3 | guerrero negro
# Processing Record 36 of Set 3 | santa quiteria do maranhao
# Processing Record 37 of Set 3 | khandagayty
# Processing Record 38 of Set 3 | lakes entrance
# Processing Record 39 of Set 3 | aykhal
# Processing Record 40 of Set 3 | college
# Processing Record 41 of Set 3 | grand baie
# Processing Record 42 of Set 3 | valparaiso
# Processing Record 43 of Set 3 | usakos
# Processing Record 44 of Set 3 | palekh
# Processing Record 45 of Set 3 | severobaykalsk
# Processing Record 46 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 3 | saldanha
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | nikolskoye
# Processing Record 50 of Set 3 | bambous virieux
# Processing Record 1 of Set 4 | kashi
# Processing Record 2 of Set 4 | canutama
# Processing Record 3 of Set 4 | banda aceh
# Processing Record 4 of Set 4 | ixtapa
# Processing Record 5 of Set 4 | iqaluit
# Processing Record 6 of Set 4 | nangomba
# Processing Record 7 of Set 4 | ha giang
# Processing Record 8 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 4 | sawtell
# Processing Record 10 of Set 4 | mutis
# Processing Record 11 of Set 4 | saurimo
# Processing Record 12 of Set 4 | tiksi
# Processing Record 13 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 4 | vardo
# Processing Record 15 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 4 | lima
# Processing Record 17 of Set 4 | puerto suarez
# Processing Record 18 of Set 4 | kilindoni
# Processing Record 19 of Set 4 | along
# Processing Record 20 of Set 4 | kodiak
# Processing Record 21 of Set 4 | chokurdakh
# Processing Record 22 of Set 4 | qarchi gak
# Processing Record 23 of Set 4 | dikson
# Processing Record 24 of Set 4 | tilichiki
# Processing Record 25 of Set 4 | shcholkine
# City not found. Skipping...
# Processing Record 26 of Set 4 | musoma
# Processing Record 27 of Set 4 | la marque
# Processing Record 28 of Set 4 | saint-pierre
# Processing Record 29 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 4 | vestmanna
# Processing Record 31 of Set 4 | araouane
# Processing Record 32 of Set 4 | praia
# Processing Record 33 of Set 4 | port lincoln
# Processing Record 34 of Set 4 | hithadhoo
# Processing Record 35 of Set 4 | te anau
# Processing Record 36 of Set 4 | mendi
# Processing Record 37 of Set 4 | havre-saint-pierre
# Processing Record 38 of Set 4 | flinders
# Processing Record 39 of Set 4 | jaguarari
# Processing Record 40 of Set 4 | yulara
# Processing Record 41 of Set 4 | grasse
# Processing Record 42 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 43 of Set 4 | berlevag
# Processing Record 44 of Set 4 | mancio lima
# Processing Record 45 of Set 4 | yar-sale
# Processing Record 46 of Set 4 | provideniya
# Processing Record 47 of Set 4 | bluff
# Processing Record 48 of Set 4 | naze
# Processing Record 49 of Set 4 | osakarovka
# Processing Record 50 of Set 4 | altus
# Processing Record 1 of Set 5 | miranda
# Processing Record 2 of Set 5 | sao filipe
# Processing Record 3 of Set 5 | belmonte
# Processing Record 4 of Set 5 | ostrovnoy
# Processing Record 5 of Set 5 | cape town
# Processing Record 6 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 5 | niltepec
# Processing Record 8 of Set 5 | touros
# Processing Record 9 of Set 5 | mildura
# Processing Record 10 of Set 5 | walvis bay
# Processing Record 11 of Set 5 | kapustin yar
# Processing Record 12 of Set 5 | devils lake
# Processing Record 13 of Set 5 | ossora
# Processing Record 14 of Set 5 | tuatapere
# Processing Record 15 of Set 5 | atbasar
# Processing Record 16 of Set 5 | laukaa
# Processing Record 17 of Set 5 | salamanca
# Processing Record 18 of Set 5 | shingu
# Processing Record 19 of Set 5 | mangualde
# Processing Record 20 of Set 5 | abu samrah
# Processing Record 21 of Set 5 | benoy
# Processing Record 22 of Set 5 | gilazi
# City not found. Skipping...
# Processing Record 23 of Set 5 | seoul
# Processing Record 24 of Set 5 | upernavik
# Processing Record 25 of Set 5 | kachug
# Processing Record 26 of Set 5 | hobyo
# Processing Record 27 of Set 5 | puri
# Processing Record 28 of Set 5 | marondera
# Processing Record 29 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 30 of Set 5 | mount isa
# Processing Record 31 of Set 5 | haines junction
# Processing Record 32 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 5 | banyo
# Processing Record 34 of Set 5 | bereda
# Processing Record 35 of Set 5 | makakilo city
# Processing Record 36 of Set 5 | cidreira
# Processing Record 37 of Set 5 | birjand
# Processing Record 38 of Set 5 | santa elena
# Processing Record 39 of Set 5 | bakchar
# Processing Record 40 of Set 5 | korsakov
# Processing Record 41 of Set 5 | sechura
# Processing Record 42 of Set 5 | amahai
# Processing Record 43 of Set 5 | merauke
# Processing Record 44 of Set 5 | gunjur
# Processing Record 45 of Set 5 | trinidad
# Processing Record 46 of Set 5 | mlimba
# Processing Record 47 of Set 5 | pingliang
# Processing Record 48 of Set 5 | lasa
# Processing Record 49 of Set 5 | paamiut
# Processing Record 50 of Set 5 | isangel
# Processing Record 1 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 2 of Set 6 | muros
# Processing Record 3 of Set 6 | lavrentiya
# Processing Record 4 of Set 6 | khatanga
# Processing Record 5 of Set 6 | hofn
# Processing Record 6 of Set 6 | acuna
# City not found. Skipping...
# Processing Record 7 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 8 of Set 6 | luorong
# Processing Record 9 of Set 6 | saskylakh
# Processing Record 10 of Set 6 | kalabo
# Processing Record 11 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 6 | ginda
# Processing Record 13 of Set 6 | carnarvon
# Processing Record 14 of Set 6 | havelock
# Processing Record 15 of Set 6 | chone
# Processing Record 16 of Set 6 | oranjemund
# Processing Record 17 of Set 6 | zorgo
# Processing Record 18 of Set 6 | takoradi
# Processing Record 19 of Set 6 | constantine
# Processing Record 20 of Set 6 | kichmengskiy gorodok
# Processing Record 21 of Set 6 | vila velha
# Processing Record 22 of Set 6 | kununurra
# Processing Record 23 of Set 6 | virginia beach
# Processing Record 24 of Set 6 | cabo san lucas
# Processing Record 25 of Set 6 | molodizhne
# Processing Record 26 of Set 6 | sao felix do xingu
# Processing Record 27 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 6 | meulaboh
# Processing Record 30 of Set 6 | victoria
# Processing Record 31 of Set 6 | marystown
# Processing Record 32 of Set 6 | krasnoye
# Processing Record 33 of Set 6 | mogadishu
# Processing Record 34 of Set 6 | mindelo
# Processing Record 35 of Set 6 | santa luzia
# Processing Record 36 of Set 6 | santa rosa
# Processing Record 37 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 6 | dhidhdhoo
# Processing Record 39 of Set 6 | baruun-urt
# Processing Record 40 of Set 6 | longyearbyen
# Processing Record 41 of Set 6 | amalfi
# Processing Record 42 of Set 6 | novyy urengoy
# Processing Record 43 of Set 6 | punto fijo
# Processing Record 44 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 45 of Set 6 | swan hill
# Processing Record 46 of Set 6 | kulhudhuffushi
# Processing Record 47 of Set 6 | paka
# Processing Record 48 of Set 6 | mecca
# Processing Record 49 of Set 6 | eganville
# Processing Record 50 of Set 6 | kijang
# Processing Record 1 of Set 7 | aleppo
# Processing Record 2 of Set 7 | leningradskiy
# Processing Record 3 of Set 7 | ifo
# Processing Record 4 of Set 7 | purpe
# Processing Record 5 of Set 7 | garowe
# Processing Record 6 of Set 7 | akcakoca
# Processing Record 7 of Set 7 | morwa
# Processing Record 8 of Set 7 | kamuli
# Processing Record 9 of Set 7 | adre
# Processing Record 10 of Set 7 | zaranj
# Processing Record 11 of Set 7 | fallon
# Processing Record 12 of Set 7 | rantauprapat
# Processing Record 13 of Set 7 | naberera
# Processing Record 14 of Set 7 | zhigansk
# Processing Record 15 of Set 7 | rimouski
# Processing Record 16 of Set 7 | tirano
# Processing Record 17 of Set 7 | shimoda
# Processing Record 18 of Set 7 | shelburne
# Processing Record 19 of Set 7 | manokwari
# Processing Record 20 of Set 7 | dingle
# Processing Record 21 of Set 7 | east liverpool
# Processing Record 22 of Set 7 | comodoro rivadavia
# Processing Record 23 of Set 7 | cascais
# Processing Record 24 of Set 7 | narsaq
# Processing Record 25 of Set 7 | havoysund
# Processing Record 26 of Set 7 | winnetka
# Processing Record 27 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 28 of Set 7 | hamilton
# Processing Record 29 of Set 7 | kamaishi
# Processing Record 30 of Set 7 | maicao
# Processing Record 31 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 7 | dorado
# Processing Record 33 of Set 7 | uruacu
# Processing Record 34 of Set 7 | jalu
# Processing Record 35 of Set 7 | kirando
# Processing Record 36 of Set 7 | aljezur
# Processing Record 37 of Set 7 | ocampo
# Processing Record 38 of Set 7 | sola
# Processing Record 39 of Set 7 | veraval
# Processing Record 40 of Set 7 | dinar
# Processing Record 41 of Set 7 | alice springs
# Processing Record 42 of Set 7 | hindupur
# Processing Record 43 of Set 7 | cockburn town
# Processing Record 44 of Set 7 | concepcion
# Processing Record 45 of Set 7 | ornskoldsvik
# Processing Record 46 of Set 7 | xuanzhou
# Processing Record 47 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 7 | esperance
# Processing Record 49 of Set 7 | geraldton
# Processing Record 50 of Set 7 | olafsvik
# Processing Record 1 of Set 8 | tocopilla
# Processing Record 2 of Set 8 | vitim
# Processing Record 3 of Set 8 | brawley
# Processing Record 4 of Set 8 | margate
# Processing Record 5 of Set 8 | salalah
# Processing Record 6 of Set 8 | clyde river
# Processing Record 7 of Set 8 | husavik
# Processing Record 8 of Set 8 | westport
# Processing Record 9 of Set 8 | severo-kurilsk
# Processing Record 10 of Set 8 | padre paraiso
# Processing Record 11 of Set 8 | ahipara
# Processing Record 12 of Set 8 | mozarlandia
# Processing Record 13 of Set 8 | monaghan
# Processing Record 14 of Set 8 | barra do bugres
# Processing Record 15 of Set 8 | faya
# Processing Record 16 of Set 8 | jennings
# Processing Record 17 of Set 8 | escanaba
# Processing Record 18 of Set 8 | talakan
# Processing Record 19 of Set 8 | atar
# Processing Record 20 of Set 8 | tonota
# Processing Record 21 of Set 8 | bilibino
# Processing Record 22 of Set 8 | severnyy
# Processing Record 23 of Set 8 | pacific grove
# Processing Record 24 of Set 8 | prince rupert
# Processing Record 25 of Set 8 | pisco
# Processing Record 26 of Set 8 | taoudenni
# Processing Record 27 of Set 8 | lively
# Processing Record 28 of Set 8 | san cristobal
# Processing Record 29 of Set 8 | san ramon
# Processing Record 30 of Set 8 | sioux lookout
# Processing Record 31 of Set 8 | carbonia
# Processing Record 32 of Set 8 | beloha
# Processing Record 33 of Set 8 | jimeta
# Processing Record 34 of Set 8 | tirodi
# Processing Record 35 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 8 | atambua
# Processing Record 37 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 8 | lashio
# Processing Record 39 of Set 8 | cabedelo
# Processing Record 40 of Set 8 | octeville
# Processing Record 41 of Set 8 | asau
# Processing Record 42 of Set 8 | severomorsk
# Processing Record 43 of Set 8 | komsomolskiy
# Processing Record 44 of Set 8 | musafirkhana
# Processing Record 45 of Set 8 | grand gaube
# Processing Record 46 of Set 8 | manta
# Processing Record 47 of Set 8 | matay
# Processing Record 48 of Set 8 | christchurch
# Processing Record 49 of Set 8 | aden
# Processing Record 50 of Set 8 | ayame
# Processing Record 1 of Set 9 | poso
# Processing Record 2 of Set 9 | boda
# Processing Record 3 of Set 9 | jalalabad
# Processing Record 4 of Set 9 | san policarpo
# Processing Record 5 of Set 9 | bismil
# Processing Record 6 of Set 9 | juanjui
# Processing Record 7 of Set 9 | pangnirtung
# Processing Record 8 of Set 9 | tasiilaq
# Processing Record 9 of Set 9 | yerbogachen
# Processing Record 10 of Set 9 | fukue
# Processing Record 11 of Set 9 | puerto carreno
# Processing Record 12 of Set 9 | chitral
# Processing Record 13 of Set 9 | quesnel
# Processing Record 14 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 9 | orgun
# City not found. Skipping...
# Processing Record 16 of Set 9 | kirensk
# Processing Record 17 of Set 9 | pringsewu
# Processing Record 18 of Set 9 | georgetown
# Processing Record 19 of Set 9 | beaverlodge
# Processing Record 20 of Set 9 | peleduy
# Processing Record 21 of Set 9 | koutsouras
# Processing Record 22 of Set 9 | waverly
# Processing Record 23 of Set 9 | cilaos
# Processing Record 24 of Set 9 | vao
# Processing Record 25 of Set 9 | povorino
# Processing Record 26 of Set 9 | taltal
# Processing Record 27 of Set 9 | naples
# Processing Record 28 of Set 9 | kruisfontein
# Processing Record 29 of Set 9 | sogne
# Processing Record 30 of Set 9 | goundi
# Processing Record 31 of Set 9 | newport
# Processing Record 32 of Set 9 | carbondale
# Processing Record 33 of Set 9 | aban
# Processing Record 34 of Set 9 | coahuayana
# Processing Record 35 of Set 9 | baiyin
# Processing Record 36 of Set 9 | santa isabel do rio negro
# Processing Record 37 of Set 9 | loukhi
# Processing Record 38 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 40 of Set 9 | ayagoz
# Processing Record 41 of Set 9 | coihueco
# Processing Record 42 of Set 9 | novi sanzhary
# Processing Record 43 of Set 9 | mitsamiouli
# Processing Record 44 of Set 9 | baglung
# Processing Record 45 of Set 9 | khuzdar
# Processing Record 46 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 9 | wampusirpi
# City not found. Skipping...
# Processing Record 48 of Set 9 | sakaraha
# Processing Record 49 of Set 9 | darnah
# Processing Record 50 of Set 9 | yanji
# Processing Record 1 of Set 10 | zaoyang
# Processing Record 2 of Set 10 | raychikhinsk
# Processing Record 3 of Set 10 | conde
# Processing Record 4 of Set 10 | mehamn
# Processing Record 5 of Set 10 | luganville
# Processing Record 6 of Set 10 | eggenfelden
# Processing Record 7 of Set 10 | vanimo
# Processing Record 8 of Set 10 | champerico
# Processing Record 9 of Set 10 | brae
# Processing Record 10 of Set 10 | santa maria
# Processing Record 11 of Set 10 | klyuchi
# Processing Record 12 of Set 10 | jacareacanga
# Processing Record 13 of Set 10 | klaksvik
# Processing Record 14 of Set 10 | uige
# Processing Record 15 of Set 10 | nome
# Processing Record 16 of Set 10 | alta floresta
# Processing Record 17 of Set 10 | alugan
# Processing Record 18 of Set 10 | palmer
# Processing Record 19 of Set 10 | hun
# Processing Record 20 of Set 10 | constitucion
# Processing Record 21 of Set 10 | labuan
# Processing Record 22 of Set 10 | port hueneme
# Processing Record 23 of Set 10 | gravdal
# Processing Record 24 of Set 10 | ko samui
# Processing Record 25 of Set 10 | katra
# Processing Record 26 of Set 10 | port hardy
# Processing Record 27 of Set 10 | ancud
# Processing Record 28 of Set 10 | san jose
# Processing Record 29 of Set 10 | srednekolymsk
# Processing Record 30 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 10 | anloga
# Processing Record 33 of Set 10 | port hedland
# Processing Record 34 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 10 | tezu
# Processing Record 36 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 37 of Set 10 | herat
# Processing Record 38 of Set 10 | dickinson
# Processing Record 39 of Set 10 | dmitrov
# Processing Record 40 of Set 10 | bacungan
# Processing Record 41 of Set 10 | ketchikan
# Processing Record 42 of Set 10 | kismayo
# Processing Record 43 of Set 10 | marzuq
# Processing Record 44 of Set 10 | miguel alves
# Processing Record 45 of Set 10 | bone
# Processing Record 46 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 10 | nabire
# Processing Record 48 of Set 10 | pangai
# Processing Record 49 of Set 10 | beli manastir
# Processing Record 50 of Set 10 | belgrade
# Processing Record 1 of Set 11 | emirdag
# Processing Record 2 of Set 11 | chuy
# Processing Record 3 of Set 11 | mattru
# Processing Record 4 of Set 11 | bonavista
# Processing Record 5 of Set 11 | lorengau
# Processing Record 6 of Set 11 | houma
# Processing Record 7 of Set 11 | mount gambier
# Processing Record 8 of Set 11 | kingman
# Processing Record 9 of Set 11 | gorele
# Processing Record 10 of Set 11 | tiarei
# Processing Record 11 of Set 11 | batemans bay
# Processing Record 12 of Set 11 | port alberni
# Processing Record 13 of Set 11 | teya
# Processing Record 14 of Set 11 | fairlie
# Processing Record 15 of Set 11 | linxia
# Processing Record 16 of Set 11 | quatre cocos
# Processing Record 17 of Set 11 | ugoofaaru
# Processing Record 18 of Set 11 | san lawrenz
# Processing Record 19 of Set 11 | mujiayingzi
# Processing Record 20 of Set 11 | shajapur
# Processing Record 21 of Set 11 | kintampo
# Processing Record 22 of Set 11 | moroto
# Processing Record 23 of Set 11 | aksarka
# Processing Record 24 of Set 11 | olivet
# Processing Record 25 of Set 11 | umm kaddadah
# Processing Record 26 of Set 11 | jomalig
# City not found. Skipping...
# Processing Record 27 of Set 11 | deqing
# Processing Record 28 of Set 11 | jalingo
# Processing Record 29 of Set 11 | samana
# Processing Record 30 of Set 11 | itarema
# Processing Record 31 of Set 11 | arandis
# Processing Record 32 of Set 11 | gallup
# Processing Record 33 of Set 11 | huangzhai
# Processing Record 34 of Set 11 | le marin
# Processing Record 35 of Set 11 | sistranda
# Processing Record 36 of Set 11 | katsuura
# Processing Record 37 of Set 11 | yumen
# Processing Record 38 of Set 11 | pevek
# Processing Record 39 of Set 11 | wuchang
# Processing Record 40 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 41 of Set 11 | poprad
# Processing Record 42 of Set 11 | snezhnogorsk
# Processing Record 43 of Set 11 | karwar
# Processing Record 44 of Set 11 | douglas
# Processing Record 45 of Set 11 | bandarbeyla
# Processing Record 46 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 47 of Set 11 | basay
# Processing Record 48 of Set 11 | chongqing
# Processing Record 49 of Set 11 | male
# Processing Record 50 of Set 11 | santiago del estero
# Processing Record 1 of Set 12 | kavieng
# Processing Record 2 of Set 12 | port-gentil
# Processing Record 3 of Set 12 | gimli
# Processing Record 4 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 5 of Set 12 | dunedin
# Processing Record 6 of Set 12 | qaqortoq
# Processing Record 7 of Set 12 | omboue
# Processing Record 8 of Set 12 | juba
# Processing Record 9 of Set 12 | ambilobe
# Processing Record 10 of Set 12 | itupiranga
# Processing Record 11 of Set 12 | kieta
# Processing Record 12 of Set 12 | hendijan
# City not found. Skipping...
# Processing Record 13 of Set 12 | imbituba
# Processing Record 14 of Set 12 | sidi ali
# Processing Record 15 of Set 12 | sinjai
# Processing Record 16 of Set 12 | rio grande
# Processing Record 17 of Set 12 | contamana
# Processing Record 18 of Set 12 | sorland
# Processing Record 19 of Set 12 | smoky lake
# Processing Record 20 of Set 12 | cabra
# Processing Record 21 of Set 12 | pavilosta
# Processing Record 22 of Set 12 | okhotsk
# Processing Record 23 of Set 12 | huicheng
# Processing Record 24 of Set 12 | salinopolis
# Processing Record 25 of Set 12 | biltine
# Processing Record 26 of Set 12 | alma
# Processing Record 27 of Set 12 | florianopolis
# Processing Record 28 of Set 12 | igarka
# Processing Record 29 of Set 12 | najran
# Processing Record 30 of Set 12 | marathon
# Processing Record 31 of Set 12 | torbay
# Processing Record 32 of Set 12 | matagami
# Processing Record 33 of Set 12 | arlit
# Processing Record 34 of Set 12 | byron bay
# Processing Record 35 of Set 12 | port hawkesbury
# Processing Record 36 of Set 12 | turayf
# Processing Record 37 of Set 12 | great yarmouth
# Processing Record 38 of Set 12 | brokopondo
# Processing Record 39 of Set 12 | kenai
# Processing Record 40 of Set 12 | tokmak
# Processing Record 41 of Set 12 | forasti
# Processing Record 42 of Set 12 | namatanai
# Processing Record 43 of Set 12 | san patricio
# Processing Record 44 of Set 12 | lieksa
# Processing Record 45 of Set 12 | chernyshevskiy
# Processing Record 46 of Set 12 | nabannagan
# Processing Record 47 of Set 12 | guasdualito
# Processing Record 48 of Set 12 | caxito
# Processing Record 49 of Set 12 | yambio
# Processing Record 50 of Set 12 | sampit
# Processing Record 1 of Set 13 | mlonggo
# Processing Record 2 of Set 13 | yenagoa
# Processing Record 3 of Set 13 | kathmandu
# Processing Record 4 of Set 13 | kautokeino
# Processing Record 5 of Set 13 | kysyl-syr
# Processing Record 6 of Set 13 | todos santos
# Processing Record 7 of Set 13 | egvekinot
# Processing Record 8 of Set 13 | camacha
# Processing Record 9 of Set 13 | pimentel
# Processing Record 10 of Set 13 | sept-iles
# Processing Record 11 of Set 13 | portland
# Processing Record 12 of Set 13 | verkhnevilyuysk
# Processing Record 13 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 13 | mansa
# Processing Record 15 of Set 13 | quelimane
# Processing Record 16 of Set 13 | urengoy
# Processing Record 17 of Set 13 | high level
# Processing Record 18 of Set 13 | tessalit
# Processing Record 19 of Set 13 | ustye
# Processing Record 20 of Set 13 | moses lake
# Processing Record 21 of Set 13 | turukhansk
# Processing Record 22 of Set 13 | acarau
# Processing Record 23 of Set 13 | tra vinh
# Processing Record 24 of Set 13 | victoria point
# Processing Record 25 of Set 13 | eydhafushi
# Processing Record 26 of Set 13 | palafrugell
# Processing Record 27 of Set 13 | piacabucu
# Processing Record 28 of Set 13 | sahuaripa
# Processing Record 29 of Set 13 | finote selam
# Processing Record 30 of Set 13 | asyut
# Processing Record 31 of Set 13 | mazatlan
# Processing Record 32 of Set 13 | calbuco
# Processing Record 33 of Set 13 | krasnoselkup
# Processing Record 34 of Set 13 | chhabra
# Processing Record 35 of Set 13 | nanlong
# Processing Record 36 of Set 13 | koshki
# Processing Record 37 of Set 13 | mareeba
# Processing Record 38 of Set 13 | kushima
# Processing Record 39 of Set 13 | guryevsk
# Processing Record 40 of Set 13 | caravelas
# Processing Record 41 of Set 13 | gigmoto
# Processing Record 42 of Set 13 | zhuhai
# Processing Record 43 of Set 13 | pueblo nuevo
# Processing Record 44 of Set 13 | darlowo
# Processing Record 45 of Set 13 | miraflores
# Processing Record 46 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 13 | satipo
# Processing Record 49 of Set 13 | chikoy
# City not found. Skipping...
# Processing Record 50 of Set 13 | klamath falls
# Processing Record 1 of Set 14 | ust-tsilma
# Processing Record 2 of Set 14 | hudson bay
# Processing Record 3 of Set 14 | alofi
# Processing Record 4 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 5 of Set 14 | gombong
# Processing Record 6 of Set 14 | mantua
# Processing Record 7 of Set 14 | iquique
# Processing Record 8 of Set 14 | urusha
# Processing Record 9 of Set 14 | saint anthony
# Processing Record 10 of Set 14 | carndonagh
# Processing Record 11 of Set 14 | kjollefjord
# Processing Record 12 of Set 14 | tesistan
# Processing Record 13 of Set 14 | kankakee
# Processing Record 14 of Set 14 | uravakonda
# Processing Record 15 of Set 14 | hurghada
# Processing Record 16 of Set 14 | sur
# Processing Record 17 of Set 14 | rio gallegos
# Processing Record 18 of Set 14 | balkhash
# Processing Record 19 of Set 14 | gamba
# Processing Record 20 of Set 14 | pereyaslovskaya
# Processing Record 21 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 14 | manbij
# Processing Record 23 of Set 14 | chazuta
# Processing Record 24 of Set 14 | luderitz
# Processing Record 25 of Set 14 | nestorion
# City not found. Skipping...
# Processing Record 26 of Set 14 | half moon bay
# Processing Record 27 of Set 14 | freeport
# Processing Record 28 of Set 14 | avera
# Processing Record 29 of Set 14 | belogradcik
# City not found. Skipping...
# Processing Record 30 of Set 14 | poum
# Processing Record 31 of Set 14 | saquisili
# Processing Record 32 of Set 14 | beira
# Processing Record 33 of Set 14 | nador
# Processing Record 34 of Set 14 | nantucket
# Processing Record 35 of Set 14 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 36 of Set 14 | sobolevo
# Processing Record 37 of Set 14 | chisinau
# Processing Record 38 of Set 14 | thale
# Processing Record 39 of Set 14 | masuguru
# Processing Record 40 of Set 14 | dzhebariki-khaya
# Processing Record 41 of Set 14 | deputatskiy
# Processing Record 42 of Set 14 | kayerkan
# Processing Record 43 of Set 14 | koslan
# Processing Record 44 of Set 14 | nanning
# Processing Record 45 of Set 14 | coquimbo
# Processing Record 46 of Set 14 | usogorsk
# Processing Record 47 of Set 14 | kattivakkam
# Processing Record 48 of Set 14 | conakry
# Processing Record 49 of Set 14 | dudinka
# Processing Record 50 of Set 14 | moerai
# Processing Record 1 of Set 15 | necochea
# Processing Record 2 of Set 15 | batavia
# Processing Record 3 of Set 15 | bolgatanga
# Processing Record 4 of Set 15 | buala
# Processing Record 5 of Set 15 | bud
# Processing Record 6 of Set 15 | morros
# Processing Record 7 of Set 15 | lomas de sargentillo
# Processing Record 8 of Set 15 | bozoum
# Processing Record 9 of Set 15 | kudahuvadhoo
# Processing Record 10 of Set 15 | yashkul
# Processing Record 11 of Set 15 | caledonia
# Processing Record 12 of Set 15 | dire
# Processing Record 13 of Set 15 | dickson
# Processing Record 14 of Set 15 | namibe
# Processing Record 15 of Set 15 | kombotion
# City not found. Skipping...
# Processing Record 16 of Set 15 | mongu
# Processing Record 17 of Set 15 | rosehearty
# Processing Record 18 of Set 15 | los andes
# Processing Record 19 of Set 15 | lossiemouth
# Processing Record 20 of Set 15 | puerto berrio
# Processing Record 21 of Set 15 | taggia
# Processing Record 22 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 15 | northam
# Processing Record 24 of Set 15 | lotoshino
# Processing Record 25 of Set 15 | bathsheba
# Processing Record 26 of Set 15 | buraydah
# Processing Record 27 of Set 15 | ruthin
# Processing Record 28 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 15 | kongolo
# Processing Record 30 of Set 15 | amboise
# Processing Record 31 of Set 15 | gandhidham
# Processing Record 32 of Set 15 | skjervoy
# Processing Record 33 of Set 15 | alta gracia
# Processing Record 34 of Set 15 | boshnyakovo
# Processing Record 35 of Set 15 | presidencia roque saenz pena
# Processing Record 36 of Set 15 | aklavik
# Processing Record 37 of Set 15 | pangody
# Processing Record 38 of Set 15 | qinzhou
# Processing Record 39 of Set 15 | zhukovka
# Processing Record 40 of Set 15 | nelson bay
# Processing Record 41 of Set 15 | selam
# Processing Record 42 of Set 15 | ambon
# Processing Record 43 of Set 15 | novobirilyussy
# Processing Record 44 of Set 15 | lata
# Processing Record 45 of Set 15 | traverse city
# Processing Record 46 of Set 15 | hami
# Processing Record 47 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 48 of Set 15 | verkh-usugli
# Processing Record 49 of Set 15 | bardiyah
# Processing Record 50 of Set 15 | lubao
# Processing Record 1 of Set 16 | kavaratti
# Processing Record 2 of Set 16 | ndele
# Processing Record 3 of Set 16 | madukkarai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 688

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Zhangye      CN  38.9342  100.4517     14.43        50           7
# 1          Lompoc      US  34.6391 -120.4579     60.01        79         100
# 2      Launceston      AU -41.4500  147.1667     66.61        57         100
# 3    Cartersville      US  34.1651  -84.7999     49.15        46           0
# 4         Mataura      NZ -46.1927  168.8643     50.49        80          77
# 5            Axim      GH   4.8699   -2.2405     78.60        83          87
# 6  Port Elizabeth      ZA -33.9180   25.5701     65.10        92          38
# 7         Rikitea      PF -23.1203 -134.9692     73.13        71          82
# 8          Barrow      US  71.2906 -156.7887     28.42        93         100
# 9            Boma      GH   7.0805   -2.1697     72.46        92          94
#
#    Wind Speed Current Description
# 0        5.66           clear sky
# 1        6.91     overcast clouds
# 2       12.66     overcast clouds
# 3        3.00           clear sky
# 4        9.78       broken clouds
# 5        5.21     overcast clouds
# 6        5.99    scattered clouds
# 7       12.88       broken clouds
# 8        9.22                mist
# 9        2.51     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Zhangye      CN  38.9342  100.4517     14.43        50           7
# 1          Lompoc      US  34.6391 -120.4579     60.01        79         100
# 2      Launceston      AU -41.4500  147.1667     66.61        57         100
# 3    Cartersville      US  34.1651  -84.7999     49.15        46           0
# 4         Mataura      NZ -46.1927  168.8643     50.49        80          77
# 5            Axim      GH   4.8699   -2.2405     78.60        83          87
# 6  Port Elizabeth      ZA -33.9180   25.5701     65.10        92          38
# 7         Rikitea      PF -23.1203 -134.9692     73.13        71          82
# 8          Barrow      US  71.2906 -156.7887     28.42        93         100
# 9            Boma      GH   7.0805   -2.1697     72.46        92          94
#
#    Wind Speed Current Description
# 0        5.66           clear sky
# 1        6.91     overcast clouds
# 2       12.66     overcast clouds
# 3        3.00           clear sky
# 4        9.78       broken clouds
# 5        5.21     overcast clouds
# 6        5.99    scattered clouds
# 7       12.88       broken clouds
# 8        9.22                mist
# 9        2.51     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
